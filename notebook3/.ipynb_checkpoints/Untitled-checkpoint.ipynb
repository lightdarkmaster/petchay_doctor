# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dense, Reshape
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD
import numpy as np
# Out:
# WARNING:tensorflow:From C:\Users\skywa\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# list devices for tensorflow
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
IMAGE_SIZE = (256, 256)  #224
BATCH_SIZE = 32  
DIRECTORY = "datasets"

# %%
train_dataset = image_dataset_from_directory(
    DIRECTORY,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE)

validation_dataset = image_dataset_from_directory(
    DIRECTORY,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE)

class_names = train_dataset.class_names
num_classes = len(class_names)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 train_dataset = image_dataset_from_directory(
#       2     DIRECTORY,
#       3     validation_split=0.2,
#       4     subset="training",
#       5     seed=123,
#       6     image_size=IMAGE_SIZE,
#       7     batch_size=BATCH_SIZE)
#       9 validation_dataset = image_dataset_from_directory(
#      10     DIRECTORY,
#      11     validation_split=0.2,
#    (...)
#      14     image_size=IMAGE_SIZE,
#      15     batch_size=BATCH_SIZE)
#      17 class_names = train_dataset.class_names
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\image_dataset.py:213, in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, **kwargs)
#     211 if seed is None:
#     212     seed = np.random.randint(1e6)
# --> 213 image_paths, labels, class_names = dataset_utils.index_directory(
#     214     directory,
#     215     labels,
#     216     formats=ALLOWLIST_FORMATS,
#     217     class_names=class_names,
#     218     shuffle=shuffle,
#     219     seed=seed,
#     220     follow_links=follow_links,
#     221 )
#     223 if label_mode == "binary" and len(class_names) != 2:
#     224     raise ValueError(
#     225         'When passing `label_mode="binary"`, there must be exactly 2 '
#     226         f"class_names. Received: class_names={class_names}"
#     227     )
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\dataset_utils.py:574, in index_directory(directory, labels, formats, class_names, shuffle, seed, follow_links)
#     572 labels_list = []
#     573 for res in results:
# --> 574     partial_filenames, partial_labels = res.get()
#     575     labels_list.append(partial_labels)
#     576     filenames += partial_filenames
#
# File ~\anaconda3\Lib\multiprocessing\pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# File ~\anaconda3\Lib\multiprocessing\pool.py:125, in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     123 job, i, func, args, kwds = task
#     124 try:
# --> 125     result = (True, func(*args, **kwds))
#     126 except Exception as e:
#     127     if wrap_exception and func is not _helper_reraises_exception:
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\dataset_utils.py:645, in index_subdirectory(directory, class_indices, follow_links, formats)
#     643 labels = []
#     644 filenames = []
# --> 645 for root, fname in valid_files:
#     646     labels.append(class_indices[dirname])
#     647     absolute_path = tf.io.gfile.join(root, fname)
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\dataset_utils.py:620, in iter_valid_files(directory, follow_links, formats)
#     618 else:
#     619     walk = os.walk(directory, followlinks=follow_links)
# --> 620 for root, _, files in sorted(walk, key=lambda x: x[0]):
#     621     for fname in sorted(files):
#     622         if fname.lower().endswith(formats):
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\lib\io\file_io.py:876, in walk_v2(top, topdown, onerror)
#     874 for item in listing:
#     875   full_path = _make_full_path(top, item)
# --> 876   if is_directory(full_path):
#     877     subdirs.append(item)
#     878   else:
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\lib\io\file_io.py:689, in is_directory(dirname)
#     679 @tf_export(v1=["gfile.IsDirectory"])
#     680 def is_directory(dirname):
#     681   """Returns whether the path is a directory or not.
#     682
#     683   Args:
#    (...)
#     687     True, if the path is a directory; False otherwise
#     688   """
# --> 689   return is_directory_v2(dirname)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\lib\io\file_io.py:703, in is_directory_v2(path)
#     694 """Returns whether the path is a directory or not.
#     695
#     696 Args:
#    (...)
#     700   True, if the path is a directory; False otherwise
#     701 """
#     702 try:
# --> 703   return _pywrap_file_io.IsDirectory(compat.path_to_bytes(path))
#     704 except errors.OpError:
#     705   return False
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x91 in position 54: invalid start byte

# %%
class_names
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 class_names
#
# NameError: name 'class_names' is not defined

# %%
base_model = MobileNetV3Large(input_shape=(*IMAGE_SIZE, 3), include_top=False, weights='imagenet')
base_model.trainable = False
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.

# %%
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(num_classes, activation='softmax')(x) 

model = Model(inputs=base_model.input, outputs=predictions)

model.compile(optimizer=Adam(learning_rate=0.0001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.compile(optimizer=Adam(learning_rate=0.0001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  rescaling_2 (Rescaling)     (None, 256, 256, 3)          0         ['input_3[0][0]']
#
#  Conv (Conv2D)               (None, 128, 128, 16)         432       ['rescaling_2[0][0]']
#
#  Conv/BatchNorm (BatchNorma  (None, 128, 128, 16)         64        ['Conv[0][0]']
#  lization)
#
#  tf.__operators__.add_56 (T  (None, 128, 128, 16)         0         ['Conv/BatchNorm[0][0]']
#  FOpLambda)
#
#  re_lu_78 (ReLU)             (None, 128, 128, 16)         0         ['tf.__operators__.add_56[0][0
#                                                                     ]']
#
#  tf.math.multiply_56 (TFOpL  (None, 128, 128, 16)         0         ['re_lu_78[0][0]']
#  ambda)
#
#  multiply_40 (Multiply)      (None, 128, 128, 16)         0         ['Conv/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_56[0][0]']
#
#  expanded_conv/depthwise (D  (None, 128, 128, 16)         144       ['multiply_40[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv/depthwise/Ba  (None, 128, 128, 16)         64        ['expanded_conv/depthwise[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  re_lu_79 (ReLU)             (None, 128, 128, 16)         0         ['expanded_conv/depthwise/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv/project (Con  (None, 128, 128, 16)         256       ['re_lu_79[0][0]']
#  v2D)
#
#  expanded_conv/project/Batc  (None, 128, 128, 16)         64        ['expanded_conv/project[0][0]'
#  hNorm (BatchNormalization)                                         ]
#
#  expanded_conv/Add (Add)     (None, 128, 128, 16)         0         ['multiply_40[0][0]',
#                                                                      'expanded_conv/project/BatchN
#                                                                     orm[0][0]']
#
#  expanded_conv_1/expand (Co  (None, 128, 128, 64)         1024      ['expanded_conv/Add[0][0]']
#  nv2D)
#
#  expanded_conv_1/expand/Bat  (None, 128, 128, 64)         256       ['expanded_conv_1/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_80 (ReLU)             (None, 128, 128, 64)         0         ['expanded_conv_1/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 129, 129, 64)         0         ['re_lu_80[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_1/depthwise   (None, 64, 64, 64)           576       ['expanded_conv_1/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 64, 64, 64)           256       ['expanded_conv_1/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_81 (ReLU)             (None, 64, 64, 64)           0         ['expanded_conv_1/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_1/project (C  (None, 64, 64, 24)           1536      ['re_lu_81[0][0]']
#  onv2D)
#
#  expanded_conv_1/project/Ba  (None, 64, 64, 24)           96        ['expanded_conv_1/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/expand (Co  (None, 64, 64, 72)           1728      ['expanded_conv_1/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_2/expand/Bat  (None, 64, 64, 72)           288       ['expanded_conv_2/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_82 (ReLU)             (None, 64, 64, 72)           0         ['expanded_conv_2/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_2/depthwise   (None, 64, 64, 72)           648       ['re_lu_82[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_2/depthwise/  (None, 64, 64, 72)           288       ['expanded_conv_2/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_83 (ReLU)             (None, 64, 64, 72)           0         ['expanded_conv_2/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_2/project (C  (None, 64, 64, 24)           1728      ['re_lu_83[0][0]']
#  onv2D)
#
#  expanded_conv_2/project/Ba  (None, 64, 64, 24)           96        ['expanded_conv_2/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/Add (Add)   (None, 64, 64, 24)           0         ['expanded_conv_1/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_2/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_3/expand (Co  (None, 64, 64, 72)           1728      ['expanded_conv_2/Add[0][0]']
#  nv2D)
#
#  expanded_conv_3/expand/Bat  (None, 64, 64, 72)           288       ['expanded_conv_3/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_84 (ReLU)             (None, 64, 64, 72)           0         ['expanded_conv_3/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 67, 67, 72)           0         ['re_lu_84[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_3/depthwise   (None, 32, 32, 72)           1800      ['expanded_conv_3/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 32, 32, 72)           288       ['expanded_conv_3/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_85 (ReLU)             (None, 32, 32, 72)           0         ['expanded_conv_3/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 72)             0         ['re_lu_85[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             1752      ['expanded_conv_3/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             0         ['expanded_conv_3/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 72)             1800      ['expanded_conv_3/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_57 (T  (None, 1, 1, 72)             0         ['expanded_conv_3/squeeze_exci
#  FOpLambda)                                                         te/Conv_1[0][0]']
#
#  re_lu_86 (ReLU)             (None, 1, 1, 72)             0         ['tf.__operators__.add_57[0][0
#                                                                     ]']
#
#  tf.math.multiply_57 (TFOpL  (None, 1, 1, 72)             0         ['re_lu_86[0][0]']
#  ambda)
#
#  expanded_conv_3/squeeze_ex  (None, 32, 32, 72)           0         ['re_lu_85[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_57[0][0]']
#
#  expanded_conv_3/project (C  (None, 32, 32, 40)           2880      ['expanded_conv_3/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_3/project/Ba  (None, 32, 32, 40)           160       ['expanded_conv_3/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/expand (Co  (None, 32, 32, 120)          4800      ['expanded_conv_3/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_4/expand/Bat  (None, 32, 32, 120)          480       ['expanded_conv_4/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_87 (ReLU)             (None, 32, 32, 120)          0         ['expanded_conv_4/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_4/depthwise   (None, 32, 32, 120)          3000      ['re_lu_87[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_4/depthwise/  (None, 32, 32, 120)          480       ['expanded_conv_4/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_88 (ReLU)             (None, 32, 32, 120)          0         ['expanded_conv_4/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 120)            0         ['re_lu_88[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 32)             3872      ['expanded_conv_4/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 32)             0         ['expanded_conv_4/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 120)            3960      ['expanded_conv_4/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_58 (T  (None, 1, 1, 120)            0         ['expanded_conv_4/squeeze_exci
#  FOpLambda)                                                         te/Conv_1[0][0]']
#
#  re_lu_89 (ReLU)             (None, 1, 1, 120)            0         ['tf.__operators__.add_58[0][0
#                                                                     ]']
#
#  tf.math.multiply_58 (TFOpL  (None, 1, 1, 120)            0         ['re_lu_89[0][0]']
#  ambda)
#
#  expanded_conv_4/squeeze_ex  (None, 32, 32, 120)          0         ['re_lu_88[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_58[0][0]']
#
#  expanded_conv_4/project (C  (None, 32, 32, 40)           4800      ['expanded_conv_4/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_4/project/Ba  (None, 32, 32, 40)           160       ['expanded_conv_4/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/Add (Add)   (None, 32, 32, 40)           0         ['expanded_conv_3/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_4/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_5/expand (Co  (None, 32, 32, 120)          4800      ['expanded_conv_4/Add[0][0]']
#  nv2D)
#
#  expanded_conv_5/expand/Bat  (None, 32, 32, 120)          480       ['expanded_conv_5/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_90 (ReLU)             (None, 32, 32, 120)          0         ['expanded_conv_5/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_5/depthwise   (None, 32, 32, 120)          3000      ['re_lu_90[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_5/depthwise/  (None, 32, 32, 120)          480       ['expanded_conv_5/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_91 (ReLU)             (None, 32, 32, 120)          0         ['expanded_conv_5/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 120)            0         ['re_lu_91[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 32)             3872      ['expanded_conv_5/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 32)             0         ['expanded_conv_5/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 120)            3960      ['expanded_conv_5/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_59 (T  (None, 1, 1, 120)            0         ['expanded_conv_5/squeeze_exci
#  FOpLambda)                                                         te/Conv_1[0][0]']
#
#  re_lu_92 (ReLU)             (None, 1, 1, 120)            0         ['tf.__operators__.add_59[0][0
#                                                                     ]']
#
#  tf.math.multiply_59 (TFOpL  (None, 1, 1, 120)            0         ['re_lu_92[0][0]']
#  ambda)
#
#  expanded_conv_5/squeeze_ex  (None, 32, 32, 120)          0         ['re_lu_91[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_59[0][0]']
#
#  expanded_conv_5/project (C  (None, 32, 32, 40)           4800      ['expanded_conv_5/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_5/project/Ba  (None, 32, 32, 40)           160       ['expanded_conv_5/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_5/Add (Add)   (None, 32, 32, 40)           0         ['expanded_conv_4/Add[0][0]',
#                                                                      'expanded_conv_5/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_6/expand (Co  (None, 32, 32, 240)          9600      ['expanded_conv_5/Add[0][0]']
#  nv2D)
#
#  expanded_conv_6/expand/Bat  (None, 32, 32, 240)          960       ['expanded_conv_6/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_60 (T  (None, 32, 32, 240)          0         ['expanded_conv_6/expand/Batch
#  FOpLambda)                                                         Norm[0][0]']
#
#  re_lu_93 (ReLU)             (None, 32, 32, 240)          0         ['tf.__operators__.add_60[0][0
#                                                                     ]']
#
#  tf.math.multiply_60 (TFOpL  (None, 32, 32, 240)          0         ['re_lu_93[0][0]']
#  ambda)
#
#  multiply_41 (Multiply)      (None, 32, 32, 240)          0         ['expanded_conv_6/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_60[0][0]']
#
#  expanded_conv_6/depthwise/  (None, 33, 33, 240)          0         ['multiply_41[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_6/depthwise   (None, 16, 16, 240)          2160      ['expanded_conv_6/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_6/depthwise/  (None, 16, 16, 240)          960       ['expanded_conv_6/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_61 (T  (None, 16, 16, 240)          0         ['expanded_conv_6/depthwise/Ba
#  FOpLambda)                                                         tchNorm[0][0]']
#
#  re_lu_94 (ReLU)             (None, 16, 16, 240)          0         ['tf.__operators__.add_61[0][0
#                                                                     ]']
#
#  tf.math.multiply_61 (TFOpL  (None, 16, 16, 240)          0         ['re_lu_94[0][0]']
#  ambda)
#
#  multiply_42 (Multiply)      (None, 16, 16, 240)          0         ['expanded_conv_6/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_61[0][0]']
#
#  expanded_conv_6/project (C  (None, 16, 16, 80)           19200     ['multiply_42[0][0]']
#  onv2D)
#
#  expanded_conv_6/project/Ba  (None, 16, 16, 80)           320       ['expanded_conv_6/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/expand (Co  (None, 16, 16, 200)          16000     ['expanded_conv_6/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_7/expand/Bat  (None, 16, 16, 200)          800       ['expanded_conv_7/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_62 (T  (None, 16, 16, 200)          0         ['expanded_conv_7/expand/Batch
#  FOpLambda)                                                         Norm[0][0]']
#
#  re_lu_95 (ReLU)             (None, 16, 16, 200)          0         ['tf.__operators__.add_62[0][0
#                                                                     ]']
#
#  tf.math.multiply_62 (TFOpL  (None, 16, 16, 200)          0         ['re_lu_95[0][0]']
#  ambda)
#
#  multiply_43 (Multiply)      (None, 16, 16, 200)          0         ['expanded_conv_7/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_62[0][0]']
#
#  expanded_conv_7/depthwise   (None, 16, 16, 200)          1800      ['multiply_43[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_7/depthwise/  (None, 16, 16, 200)          800       ['expanded_conv_7/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_63 (T  (None, 16, 16, 200)          0         ['expanded_conv_7/depthwise/Ba
#  FOpLambda)                                                         tchNorm[0][0]']
#
#  re_lu_96 (ReLU)             (None, 16, 16, 200)          0         ['tf.__operators__.add_63[0][0
#                                                                     ]']
#
#  tf.math.multiply_63 (TFOpL  (None, 16, 16, 200)          0         ['re_lu_96[0][0]']
#  ambda)
#
#  multiply_44 (Multiply)      (None, 16, 16, 200)          0         ['expanded_conv_7/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_63[0][0]']
#
#  expanded_conv_7/project (C  (None, 16, 16, 80)           16000     ['multiply_44[0][0]']
#  onv2D)
#
#  expanded_conv_7/project/Ba  (None, 16, 16, 80)           320       ['expanded_conv_7/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/Add (Add)   (None, 16, 16, 80)           0         ['expanded_conv_6/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_7/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_8/expand (Co  (None, 16, 16, 184)          14720     ['expanded_conv_7/Add[0][0]']
#  nv2D)
#
#  expanded_conv_8/expand/Bat  (None, 16, 16, 184)          736       ['expanded_conv_8/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_64 (T  (None, 16, 16, 184)          0         ['expanded_conv_8/expand/Batch
#  FOpLambda)                                                         Norm[0][0]']
#
#  re_lu_97 (ReLU)             (None, 16, 16, 184)          0         ['tf.__operators__.add_64[0][0
#                                                                     ]']
#
#  tf.math.multiply_64 (TFOpL  (None, 16, 16, 184)          0         ['re_lu_97[0][0]']
#  ambda)
#
#  multiply_45 (Multiply)      (None, 16, 16, 184)          0         ['expanded_conv_8/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_64[0][0]']
#
#  expanded_conv_8/depthwise   (None, 16, 16, 184)          1656      ['multiply_45[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_8/depthwise/  (None, 16, 16, 184)          736       ['expanded_conv_8/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_65 (T  (None, 16, 16, 184)          0         ['expanded_conv_8/depthwise/Ba
#  FOpLambda)                                                         tchNorm[0][0]']
#
#  re_lu_98 (ReLU)             (None, 16, 16, 184)          0         ['tf.__operators__.add_65[0][0
#                                                                     ]']
#
#  tf.math.multiply_65 (TFOpL  (None, 16, 16, 184)          0         ['re_lu_98[0][0]']
#  ambda)
#
#  multiply_46 (Multiply)      (None, 16, 16, 184)          0         ['expanded_conv_8/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_65[0][0]']
#
#  expanded_conv_8/project (C  (None, 16, 16, 80)           14720     ['multiply_46[0][0]']
#  onv2D)
#
#  expanded_conv_8/project/Ba  (None, 16, 16, 80)           320       ['expanded_conv_8/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_8/Add (Add)   (None, 16, 16, 80)           0         ['expanded_conv_7/Add[0][0]',
#                                                                      'expanded_conv_8/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_9/expand (Co  (None, 16, 16, 184)          14720     ['expanded_conv_8/Add[0][0]']
#  nv2D)
#
#  expanded_conv_9/expand/Bat  (None, 16, 16, 184)          736       ['expanded_conv_9/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_66 (T  (None, 16, 16, 184)          0         ['expanded_conv_9/expand/Batch
#  FOpLambda)                                                         Norm[0][0]']
#
#  re_lu_99 (ReLU)             (None, 16, 16, 184)          0         ['tf.__operators__.add_66[0][0
#                                                                     ]']
#
#  tf.math.multiply_66 (TFOpL  (None, 16, 16, 184)          0         ['re_lu_99[0][0]']
#  ambda)
#
#  multiply_47 (Multiply)      (None, 16, 16, 184)          0         ['expanded_conv_9/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_66[0][0]']
#
#  expanded_conv_9/depthwise   (None, 16, 16, 184)          1656      ['multiply_47[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_9/depthwise/  (None, 16, 16, 184)          736       ['expanded_conv_9/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_67 (T  (None, 16, 16, 184)          0         ['expanded_conv_9/depthwise/Ba
#  FOpLambda)                                                         tchNorm[0][0]']
#
#  re_lu_100 (ReLU)            (None, 16, 16, 184)          0         ['tf.__operators__.add_67[0][0
#                                                                     ]']
#
#  tf.math.multiply_67 (TFOpL  (None, 16, 16, 184)          0         ['re_lu_100[0][0]']
#  ambda)
#
#  multiply_48 (Multiply)      (None, 16, 16, 184)          0         ['expanded_conv_9/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_67[0][0]']
#
#  expanded_conv_9/project (C  (None, 16, 16, 80)           14720     ['multiply_48[0][0]']
#  onv2D)
#
#  expanded_conv_9/project/Ba  (None, 16, 16, 80)           320       ['expanded_conv_9/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_9/Add (Add)   (None, 16, 16, 80)           0         ['expanded_conv_8/Add[0][0]',
#                                                                      'expanded_conv_9/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_10/expand (C  (None, 16, 16, 480)          38400     ['expanded_conv_9/Add[0][0]']
#  onv2D)
#
#  expanded_conv_10/expand/Ba  (None, 16, 16, 480)          1920      ['expanded_conv_10/expand[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
# ...
#  expanded_conv_13/depthwise  (None, 8, 8, 960)            24000     ['multiply_55[0][0]']
#   (DepthwiseConv2D)
#
#  expanded_conv_13/depthwise  (None, 8, 8, 960)            3840      ['expanded_conv_13/depthwise[0
#  /BatchNorm (BatchNormaliza                                         ][0]']
#  tion)
#
#  tf.__operators__.add_78 (T  (None, 8, 8, 960)            0         ['expanded_conv_13/depthwise/B
#  FOpLambda)                                                         atchNorm[0][0]']
#
#  re_lu_111 (ReLU)            (None, 8, 8, 960)            0         ['tf.__operators__.add_78[0][0
#                                                                     ]']
#
#  tf.math.multiply_78 (TFOpL  (None, 8, 8, 960)            0         ['re_lu_111[0][0]']
#  ambda)
#
#  multiply_56 (Multiply)      (None, 8, 8, 960)            0         ['expanded_conv_13/depthwise/B
#                                                                     atchNorm[0][0]',
#                                                                      'tf.math.multiply_78[0][0]']
#
#  expanded_conv_13/squeeze_e  (None, 1, 1, 960)            0         ['multiply_56[0][0]']
#  xcite/AvgPool (GlobalAvera
#  gePooling2D)
#
#  expanded_conv_13/squeeze_e  (None, 1, 1, 240)            230640    ['expanded_conv_13/squeeze_exc
#  xcite/Conv (Conv2D)                                                ite/AvgPool[0][0]']
#
#  expanded_conv_13/squeeze_e  (None, 1, 1, 240)            0         ['expanded_conv_13/squeeze_exc
#  xcite/Relu (ReLU)                                                  ite/Conv[0][0]']
#
#  expanded_conv_13/squeeze_e  (None, 1, 1, 960)            231360    ['expanded_conv_13/squeeze_exc
#  xcite/Conv_1 (Conv2D)                                              ite/Relu[0][0]']
#
#  tf.__operators__.add_79 (T  (None, 1, 1, 960)            0         ['expanded_conv_13/squeeze_exc
#  FOpLambda)                                                         ite/Conv_1[0][0]']
#
#  re_lu_112 (ReLU)            (None, 1, 1, 960)            0         ['tf.__operators__.add_79[0][0
#                                                                     ]']
#
#  tf.math.multiply_79 (TFOpL  (None, 1, 1, 960)            0         ['re_lu_112[0][0]']
#  ambda)
#
#  expanded_conv_13/squeeze_e  (None, 8, 8, 960)            0         ['multiply_56[0][0]',
#  xcite/Mul (Multiply)                                                'tf.math.multiply_79[0][0]']
#
#  expanded_conv_13/project (  (None, 8, 8, 160)            153600    ['expanded_conv_13/squeeze_exc
#  Conv2D)                                                            ite/Mul[0][0]']
#
#  expanded_conv_13/project/B  (None, 8, 8, 160)            640       ['expanded_conv_13/project[0][
#  atchNorm (BatchNormalizati                                         0]']
#  on)
#
#  expanded_conv_13/Add (Add)  (None, 8, 8, 160)            0         ['expanded_conv_12/project/Bat
#                                                                     chNorm[0][0]',
#                                                                      'expanded_conv_13/project/Bat
#                                                                     chNorm[0][0]']
#
#  expanded_conv_14/expand (C  (None, 8, 8, 960)            153600    ['expanded_conv_13/Add[0][0]']
#  onv2D)
#
#  expanded_conv_14/expand/Ba  (None, 8, 8, 960)            3840      ['expanded_conv_14/expand[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  tf.__operators__.add_80 (T  (None, 8, 8, 960)            0         ['expanded_conv_14/expand/Batc
#  FOpLambda)                                                         hNorm[0][0]']
#
#  re_lu_113 (ReLU)            (None, 8, 8, 960)            0         ['tf.__operators__.add_80[0][0
#                                                                     ]']
#
#  tf.math.multiply_80 (TFOpL  (None, 8, 8, 960)            0         ['re_lu_113[0][0]']
#  ambda)
#
#  multiply_57 (Multiply)      (None, 8, 8, 960)            0         ['expanded_conv_14/expand/Batc
#                                                                     hNorm[0][0]',
#                                                                      'tf.math.multiply_80[0][0]']
#
#  expanded_conv_14/depthwise  (None, 8, 8, 960)            24000     ['multiply_57[0][0]']
#   (DepthwiseConv2D)
#
#  expanded_conv_14/depthwise  (None, 8, 8, 960)            3840      ['expanded_conv_14/depthwise[0
#  /BatchNorm (BatchNormaliza                                         ][0]']
#  tion)
#
#  tf.__operators__.add_81 (T  (None, 8, 8, 960)            0         ['expanded_conv_14/depthwise/B
#  FOpLambda)                                                         atchNorm[0][0]']
#
#  re_lu_114 (ReLU)            (None, 8, 8, 960)            0         ['tf.__operators__.add_81[0][0
#                                                                     ]']
#
#  tf.math.multiply_81 (TFOpL  (None, 8, 8, 960)            0         ['re_lu_114[0][0]']
#  ambda)
#
#  multiply_58 (Multiply)      (None, 8, 8, 960)            0         ['expanded_conv_14/depthwise/B
#                                                                     atchNorm[0][0]',
#                                                                      'tf.math.multiply_81[0][0]']
#
#  expanded_conv_14/squeeze_e  (None, 1, 1, 960)            0         ['multiply_58[0][0]']
#  xcite/AvgPool (GlobalAvera
#  gePooling2D)
#
#  expanded_conv_14/squeeze_e  (None, 1, 1, 240)            230640    ['expanded_conv_14/squeeze_exc
#  xcite/Conv (Conv2D)                                                ite/AvgPool[0][0]']
#
#  expanded_conv_14/squeeze_e  (None, 1, 1, 240)            0         ['expanded_conv_14/squeeze_exc
#  xcite/Relu (ReLU)                                                  ite/Conv[0][0]']
#
#  expanded_conv_14/squeeze_e  (None, 1, 1, 960)            231360    ['expanded_conv_14/squeeze_exc
#  xcite/Conv_1 (Conv2D)                                              ite/Relu[0][0]']
#
#  tf.__operators__.add_82 (T  (None, 1, 1, 960)            0         ['expanded_conv_14/squeeze_exc
#  FOpLambda)                                                         ite/Conv_1[0][0]']
#
#  re_lu_115 (ReLU)            (None, 1, 1, 960)            0         ['tf.__operators__.add_82[0][0
#                                                                     ]']
#
#  tf.math.multiply_82 (TFOpL  (None, 1, 1, 960)            0         ['re_lu_115[0][0]']
#  ambda)
#
#  expanded_conv_14/squeeze_e  (None, 8, 8, 960)            0         ['multiply_58[0][0]',
#  xcite/Mul (Multiply)                                                'tf.math.multiply_82[0][0]']
#
#  expanded_conv_14/project (  (None, 8, 8, 160)            153600    ['expanded_conv_14/squeeze_exc
#  Conv2D)                                                            ite/Mul[0][0]']
#
#  expanded_conv_14/project/B  (None, 8, 8, 160)            640       ['expanded_conv_14/project[0][
#  atchNorm (BatchNormalizati                                         0]']
#  on)
#
#  expanded_conv_14/Add (Add)  (None, 8, 8, 160)            0         ['expanded_conv_13/Add[0][0]',
#                                                                      'expanded_conv_14/project/Bat
#                                                                     chNorm[0][0]']
#
#  Conv_1 (Conv2D)             (None, 8, 8, 960)            153600    ['expanded_conv_14/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNor  (None, 8, 8, 960)            3840      ['Conv_1[0][0]']
#  malization)
#
#  tf.__operators__.add_83 (T  (None, 8, 8, 960)            0         ['Conv_1/BatchNorm[0][0]']
#  FOpLambda)
#
#  re_lu_116 (ReLU)            (None, 8, 8, 960)            0         ['tf.__operators__.add_83[0][0
#                                                                     ]']
#
#  tf.math.multiply_83 (TFOpL  (None, 8, 8, 960)            0         ['re_lu_116[0][0]']
#  ambda)
#
#  multiply_59 (Multiply)      (None, 8, 8, 960)            0         ['Conv_1/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_83[0][0]']
#
#  global_average_pooling2d_2  (None, 960)                  0         ['multiply_59[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 1024)                 984064    ['global_average_pooling2d_2[0
#                                                                     ][0]']
#
#  dense_5 (Dense)             (None, 5)                    5125      ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 3985541 (15.20 MB)
# Trainable params: 989189 (3.77 MB)
# Non-trainable params: 2996352 (11.43 MB)
# __________________________________________________________________________________________________

# %%
print(len(model.layers))
# Out:
# 266

# %%
history = model.fit(
    train_dataset,
    epochs=10,
    validation_data=validation_dataset)
# Out:
# Epoch 1/10
# 171/183 [===========================>..] - ETA: 4s - loss: 0.0987 - accuracy: 0.9784
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 history = model.fit(
#       2     train_dataset,
#       3     epochs=10,
#       4     validation_data=validation_dataset)
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node decode_image/DecodeImage defined at (most recent call last):
# <stack traces unavailable>
# Unknown image file format. One of JPEG, PNG, GIF, BMP required.
# 	 [[{{node decode_image/DecodeImage}}]]
# 	 [[IteratorGetNext]] [Op:__inference_train_function_28944]

# %%
base_model.trainable = True

fine_tune_at = 100

for layer in base_model.layers[:fine_tune_at]:
    layer.trainable =  False

model.compile(loss='sparse_categorical_crossentropy',
              optimizer = Adam(learning_rate=1e-5),
              metrics=['accuracy'])

history_fine = model.fit(train_dataset,
                         epochs=1,
                         validation_data=validation_dataset)
# Out:
# 183/183 [==============================] - ETA: 0s - loss: 0.3622 - accuracy: 0.8807
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[37], line 12
#       6     layer.trainable =  False
#       8 model.compile(loss='sparse_categorical_crossentropy',
#       9               optimizer = Adam(learning_rate=1e-5),
#      10               metrics=['accuracy'])
# ---> 12 history_fine = model.fit(train_dataset,
#      13                          epochs=1,
#      14                          validation_data=validation_dataset)
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node decode_image/DecodeImage defined at (most recent call last):
# <stack traces unavailable>
# Unknown image file format. One of JPEG, PNG, GIF, BMP required.
# 	 [[{{node decode_image/DecodeImage}}]]
# 	 [[IteratorGetNext]] [Op:__inference_test_function_39316]

# %%
img_path ="C:/Users/skywa/Notebook3/dataset/Bacterial Spot/zs.jpg"

img = tf.keras.utils.load_img(
    img_path, target_size= IMAGE_SIZE
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

# %%
predictions = model.predict(img_array)
score = tf.nn.softmax(predictions)

print(
    "This image most likely belongs to {} ."
    .format(class_names[np.argmax(score)])
)

# %%
model.summary()

# %%
model.save('C:/Users/skywa/notebook3/')

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

with open('bokchoymodel.tflite', 'wb') as f:
  f.write(tflite_model)
